# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import keras.backend as K
import tensorflow as tf

from scipy.spatial.distance import jensenshannon
from numpy import asarray

kl_div = tf.keras.losses.KLDivergence()
 
# calculate the js divergence
def js_divergence(p, q):
	m = 0.5 * (p + q)
	return 0.5 * kl_div(p, m) + 0.5 * kl_div(q, m)

def js_distance(y_true, y_pred):
  return K.sqrt(js_divergence(y_true, y_pred))
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Load Data

# %%
import pandas as pd
import numpy as np

def load_data():
  # load your data using this function
  # url = 'https://raw.githubusercontent.com/jordanchtan/EvaluationData/master/ExpressData/2_No_Likes.csv'
  url = 'https://raw.githubusercontent.com/jordanchtan/EvaluationData/master/ExpressDataPre/EmoBank_Writer_All.csv'
  df = pd.read_csv(url, encoding='utf8')
  df = df[df['text'].apply(lambda x: isinstance(x, str))]
  
  data = df['text']
  labels = df[['V','A','D']]

  data = data.values
  labels = labels.values

  return data, labels

# %% [markdown]
# # Create Model

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Conv1D, MaxPooling1D, Flatten, Embedding
from keras.utils import plot_model

metrics = ['mean_squared_error', 'mean_absolute_error', js_distance]

def create_model(embedding_layer):
  model = Sequential()
  model.add(embedding_layer)
  model.add(Dense(units=300, activation='relu'))
  model.add(Flatten())
  model.add(Dense(units=3, activation='relu'))

  # model.compile(loss='kullback_leibler_divergence', optimizer='adam', metrics=metrics)
  # model.compile(loss=js_divergence, optimizer='adam', metrics=metrics)
  model.compile(loss='mean_squared_error', optimizer='adam', metrics=metrics)
  print(model.summary())
  from keras.utils.vis_utils import plot_model
  plot_model(model, to_file='5.5_Express_Retro_FB.png', show_shapes=True, show_layer_names=True)

  return model

# %% [markdown]
# # Train and Evaluate Model

# %%
import nltk
nltk.download('stopwords')
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from sklearn.model_selection import train_test_split


def train_and_evaluate_model(model, data_train, labels_train, data_test, labels_test):
  print("Training:")
  # data_train, data_val, labels_train, labels_val = train_test_split(data_train, labels_train, test_size=0.2, shuffle=True)
  data_test, data_val, labels_test, labels_val = train_test_split(data_test, labels_test, test_size=0.5, shuffle=True)

  model.fit(data_train, labels_train, 
        epochs=6, batch_size=128, verbose=1, shuffle=True,
        validation_data=(data_val, labels_val))
  
  print("Evaluating:")
  scores = model.evaluate(data_test, labels_test, verbose=1)
  print("Final scores for fold:")
  print(model.metrics_names, scores) 
  return scores
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Run Evaluation

# %%
data, labels = load_data()
print(len(data))
useHoldout = False

min_reacts = 1
# if (len(data) > 10000):
#   useHoldout = True
# Out:
# 10277

# %% [markdown]
# Prep embeddings

# %%
from gensim.models.keyedvectors import KeyedVectors
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Embedding

# path = './drive/My Drive/Colab Notebooks/Store/GoogleNews-vectors-negative300.bin.gz'
path = './drive/My Drive/Colab Notebooks/Store/retro_fb_w2v_model.txt'

# embedding_model = KeyedVectors.load_word2vec_format(path, binary=True)
# embedding_layer = embedding_model.wv.get_keras_embedding(train_embeddings=False)

# vocabulary = {word: vector.index for word, vector in embedding_model.vocab.items()} 
# tk = Tokenizer(num_words=len(vocabulary)) 
# tk.word_index = vocabulary 
# encoded_data = tk.texts_to_sequences(data)
# max_length = len(max(encoded_data, key=len))
# padded_data = pad_sequences(encoded_data, maxlen=max_length, padding='post')
# data = padded_data

embedding_dim = 100
t = Tokenizer()
t.fit_on_texts(data)
vocab_size = len(t.word_index) + 1
# integer encode the documents
encoded_data = t.texts_to_sequences(data)
max_length = len(max(encoded_data, key=len))
padded_data = pad_sequences(encoded_data, maxlen=max_length, padding='post')
data = padded_data

# MAX_NB_WORDS = 200000
word2vec = KeyedVectors.load_word2vec_format(path, binary=False)

word_index = t.word_index
nb_words = min(len(word_index), len(word_index))+1
# nb_words = min(MAX_NB_WORDS, len(word_index))+1

embedding_matrix = np.zeros((nb_words, embedding_dim))
for word, i in word_index.items():
    if word in word2vec.vocab:
        embedding_matrix[i] = word2vec.word_vec(word)
# print('Null word embeddings: %d' % np.sum(np.sum(embedding_matrix, axis=1) == 0))

embedding_layer = Embedding(embedding_matrix.shape[0], # or len(word_index) + 1
                            embedding_matrix.shape[1], # or EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)
# Out:
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:253: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
print(data.shape)
print(max_length)
# Out:
# (10277, 124)
# 124

# %% [markdown]
# K-Fold

# %%
from sklearn.model_selection import KFold
from sklearn.preprocessing import normalize


if not useHoldout:
  print("KFOLD")  
  n_folds = 5
  kf = KFold(n_folds, shuffle=True)
  i = 0

  # Define per-fold score containers
  scores_per_fold = []

  for train_index, test_index in kf.split(data):
    print("Running Fold", i+1, "/", n_folds)
    data_train, data_test = data[train_index], data[test_index]
    labels_train, labels_test = labels[train_index], labels[test_index]



    #process
    # vectorizer = CountVectorizer(max_features=5000)
    # # vectorizer = CountVectorizer(binary=True, stop_words=stopwords.words('english'), 
    # #                             lowercase=True, min_df=3, max_df=0.9, max_features=5000)
    # data_train = vectorizer.fit_transform(data_train.astype('U'))

    # data_test = vectorizer.transform(data_test.astype('U'))
    # end

    
    
    model = None # Clearing the NN.
    model = create_model(embedding_layer)

    scores = train_and_evaluate_model(model, data_train, labels_train, data_test, labels_test)
    scores_per_fold.append(scores)

    i += 1
# Out:
# KFOLD
# Running Fold 1 / 5
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 124, 100)          1632100
# _________________________________________________________________
# dense_1 (Dense)              (None, 124, 300)          30300
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 37200)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 111603
# =================================================================
# Total params: 1,774,003
# Trainable params: 141,903
# Non-trainable params: 1,632,100
# _________________________________________________________________
# None
# Training:
# Train on 8221 samples, validate on 1028 samples
# Epoch 1/6
# 8221/8221 [==============================] - 3s 382us/step - loss: 1.1772 - mean_squared_error: 1.1772 - mean_absolute_error: 0.7267 - js_distance: 0.0000e+00 - val_loss: 0.1122 - val_mean_squared_error: 0.1122 - val_mean_absolute_error: 0.2500 - val_js_distance: 0.0000e+00
# Epoch 2/6
# 8221/8221 [==============================] - 3s 317us/step - loss: 0.1077 - mean_squared_error: 0.1077 - mean_absolute_error: 0.2419 - js_distance: 0.0000e+00 - val_loss: 0.1001 - val_mean_squared_error: 0.1001 - val_mean_absolute_error: 0.2294 - val_js_distance: 0.0000e+00
# Epoch 3/6
# 8221/8221 [==============================] - 3s 317us/step - loss: 0.0984 - mean_squared_error: 0.0984 - mean_absolute_error: 0.2269 - js_distance: 0.0000e+00 - val_loss: 0.0986 - val_mean_squared_error: 0.0986 - val_mean_absolute_error: 0.2265 - val_js_distance: 0.0000e+00
# Epoch 4/6
# 8221/8221 [==============================] - 3s 315us/step - loss: 0.0948 - mean_squared_error: 0.0948 - mean_absolute_error: 0.2212 - js_distance: 0.0000e+00 - val_loss: 0.0950 - val_mean_squared_error: 0.0950 - val_mean_absolute_error: 0.2166 - val_js_distance: 0.0000e+00
# Epoch 5/6
# 8221/8221 [==============================] - 3s 319us/step - loss: 0.0924 - mean_squared_error: 0.0924 - mean_absolute_error: 0.2173 - js_distance: 0.0000e+00 - val_loss: 0.0959 - val_mean_squared_error: 0.0959 - val_mean_absolute_error: 0.2231 - val_js_distance: 0.0000e+00
# Epoch 6/6
# 8221/8221 [==============================] - 3s 318us/step - loss: 0.0901 - mean_squared_error: 0.0901 - mean_absolute_error: 0.2143 - js_distance: 0.0000e+00 - val_loss: 0.0932 - val_mean_squared_error: 0.0932 - val_mean_absolute_error: 0.2162 - val_js_distance: 0.0000e+00
# Evaluating:
# 1028/1028 [==============================] - 0s 127us/step
# Final scores for fold:
# ['loss', 'mean_squared_error', 'mean_absolute_error', 'js_distance'] [0.09350393219680637, 0.09350394457578659, 0.21720808744430542, 0.0]
# Running Fold 2 / 5
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 124, 100)          1632100
# _________________________________________________________________
# dense_3 (Dense)              (None, 124, 300)          30300
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 37200)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 3)                 111603
# =================================================================
# Total params: 1,774,003
# Trainable params: 141,903
# Non-trainable params: 1,632,100
# _________________________________________________________________
# None
# Training:
# Train on 8221 samples, validate on 1028 samples
# Epoch 1/6
# 8221/8221 [==============================] - 3s 331us/step - loss: 1.2286 - mean_squared_error: 1.2286 - mean_absolute_error: 0.7449 - js_distance: 0.0000e+00 - val_loss: 0.1257 - val_mean_squared_error: 0.1257 - val_mean_absolute_error: 0.2610 - val_js_distance: 0.0000e+00
# Epoch 2/6
# 8221/8221 [==============================] - 3s 315us/step - loss: 0.1075 - mean_squared_error: 0.1075 - mean_absolute_error: 0.2416 - js_distance: 0.0000e+00 - val_loss: 0.1083 - val_mean_squared_error: 0.1083 - val_mean_absolute_error: 0.2383 - val_js_distance: 0.0000e+00
# Epoch 3/6
# 8221/8221 [==============================] - 3s 317us/step - loss: 0.0984 - mean_squared_error: 0.0984 - mean_absolute_error: 0.2270 - js_distance: 0.0000e+00 - val_loss: 0.1025 - val_mean_squared_error: 0.1025 - val_mean_absolute_error: 0.2298 - val_js_distance: 0.0000e+00
# Epoch 4/6
# 8221/8221 [==============================] - 3s 318us/step - loss: 0.0947 - mean_squared_error: 0.0947 - mean_absolute_error: 0.2211 - js_distance: 0.0000e+00 - val_loss: 0.1035 - val_mean_squared_error: 0.1035 - val_mean_absolute_error: 0.2322 - val_js_distance: 0.0000e+00
# Epoch 5/6
# 8221/8221 [==============================] - 3s 316us/step - loss: 0.0922 - mean_squared_error: 0.0922 - mean_absolute_error: 0.2176 - js_distance: 0.0000e+00 - val_loss: 0.0999 - val_mean_squared_error: 0.0999 - val_mean_absolute_error: 0.2243 - val_js_distance: 0.0000e+00
# Epoch 6/6
# 8221/8221 [==============================] - 3s 320us/step - loss: 0.0901 - mean_squared_error: 0.0901 - mean_absolute_error: 0.2148 - js_distance: 0.0000e+00 - val_loss: 0.0972 - val_mean_squared_error: 0.0972 - val_mean_absolute_error: 0.2243 - val_js_distance: 0.0000e+00
# Evaluating:
# 1028/1028 [==============================] - 0s 124us/step
# Final scores for fold:
# ['loss', 'mean_squared_error', 'mean_absolute_error', 'js_distance'] [0.0934905567521715, 0.09349056333303452, 0.21800269186496735, 0.0]
# Running Fold 3 / 5
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 124, 100)          1632100
# _________________________________________________________________
# dense_5 (Dense)              (None, 124, 300)          30300
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 37200)             0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 111603
# =================================================================
# Total params: 1,774,003
# Trainable params: 141,903
# Non-trainable params: 1,632,100
# _________________________________________________________________
# None
# Training:
# Train on 8222 samples, validate on 1028 samples
# Epoch 1/6
# 8222/8222 [==============================] - 3s 330us/step - loss: 1.2087 - mean_squared_error: 1.2087 - mean_absolute_error: 0.7343 - js_distance: 0.0000e+00 - val_loss: 0.1056 - val_mean_squared_error: 0.1056 - val_mean_absolute_error: 0.2439 - val_js_distance: 0.0000e+00
# Epoch 2/6
# 8222/8222 [==============================] - 3s 315us/step - loss: 0.1080 - mean_squared_error: 0.1080 - mean_absolute_error: 0.2410 - js_distance: 0.0000e+00 - val_loss: 0.0935 - val_mean_squared_error: 0.0935 - val_mean_absolute_error: 0.2243 - val_js_distance: 0.0000e+00
# Epoch 3/6
# 8222/8222 [==============================] - 3s 315us/step - loss: 0.0996 - mean_squared_error: 0.0996 - mean_absolute_error: 0.2277 - js_distance: 0.0000e+00 - val_loss: 0.0914 - val_mean_squared_error: 0.0914 - val_mean_absolute_error: 0.2184 - val_js_distance: 0.0000e+00
# Epoch 4/6
# 8222/8222 [==============================] - 3s 317us/step - loss: 0.0963 - mean_squared_error: 0.0963 - mean_absolute_error: 0.2222 - js_distance: 0.0000e+00 - val_loss: 0.0878 - val_mean_squared_error: 0.0878 - val_mean_absolute_error: 0.2140 - val_js_distance: 0.0000e+00
# Epoch 5/6
# 8222/8222 [==============================] - 3s 316us/step - loss: 0.0940 - mean_squared_error: 0.0940 - mean_absolute_error: 0.2197 - js_distance: 0.0000e+00 - val_loss: 0.0927 - val_mean_squared_error: 0.0927 - val_mean_absolute_error: 0.2203 - val_js_distance: 0.0000e+00
# Epoch 6/6
# 8222/8222 [==============================] - 3s 316us/step - loss: 0.0915 - mean_squared_error: 0.0915 - mean_absolute_error: 0.2160 - js_distance: 0.0000e+00 - val_loss: 0.0881 - val_mean_squared_error: 0.0881 - val_mean_absolute_error: 0.2138 - val_js_distance: 0.0000e+00
# Evaluating:
# 1027/1027 [==============================] - 0s 123us/step
# Final scores for fold:
# ['loss', 'mean_squared_error', 'mean_absolute_error', 'js_distance'] [0.09332361936337064, 0.09332362562417984, 0.21845851838588715, 0.0]
# Running Fold 4 / 5
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 124, 100)          1632100
# _________________________________________________________________
# dense_7 (Dense)              (None, 124, 300)          30300
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 37200)             0
# _________________________________________________________________
# dense_8 (Dense)              (None, 3)                 111603
# =================================================================
# Total params: 1,774,003
# Trainable params: 141,903
# Non-trainable params: 1,632,100
# _________________________________________________________________
# None
# Training:
# Train on 8222 samples, validate on 1028 samples
# Epoch 1/6
# 8222/8222 [==============================] - 3s 330us/step - loss: 1.1897 - mean_squared_error: 1.1897 - mean_absolute_error: 0.7278 - js_distance: 0.0000e+00 - val_loss: 0.1190 - val_mean_squared_error: 0.1190 - val_mean_absolute_error: 0.2587 - val_js_distance: 0.0000e+00
# Epoch 2/6
# 8222/8222 [==============================] - 3s 318us/step - loss: 0.1080 - mean_squared_error: 0.1080 - mean_absolute_error: 0.2410 - js_distance: 0.0000e+00 - val_loss: 0.1018 - val_mean_squared_error: 0.1018 - val_mean_absolute_error: 0.2356 - val_js_distance: 0.0000e+00
# Epoch 3/6
# 8222/8222 [==============================] - 3s 320us/step - loss: 0.0986 - mean_squared_error: 0.0986 - mean_absolute_error: 0.2267 - js_distance: 0.0000e+00 - val_loss: 0.0976 - val_mean_squared_error: 0.0976 - val_mean_absolute_error: 0.2269 - val_js_distance: 0.0000e+00
# Epoch 4/6
# 8222/8222 [==============================] - 3s 318us/step - loss: 0.0941 - mean_squared_error: 0.0941 - mean_absolute_error: 0.2195 - js_distance: 0.0000e+00 - val_loss: 0.0972 - val_mean_squared_error: 0.0972 - val_mean_absolute_error: 0.2289 - val_js_distance: 0.0000e+00
# Epoch 5/6
# 8222/8222 [==============================] - 3s 315us/step - loss: 0.0918 - mean_squared_error: 0.0918 - mean_absolute_error: 0.2161 - js_distance: 0.0000e+00 - val_loss: 0.0960 - val_mean_squared_error: 0.0960 - val_mean_absolute_error: 0.2251 - val_js_distance: 0.0000e+00
# Epoch 6/6
# 8222/8222 [==============================] - 3s 317us/step - loss: 0.0902 - mean_squared_error: 0.0902 - mean_absolute_error: 0.2143 - js_distance: 0.0000e+00 - val_loss: 0.0941 - val_mean_squared_error: 0.0941 - val_mean_absolute_error: 0.2203 - val_js_distance: 0.0000e+00
# Evaluating:
# 1027/1027 [==============================] - 0s 122us/step
# Final scores for fold:
# ['loss', 'mean_squared_error', 'mean_absolute_error', 'js_distance'] [0.09587565748548786, 0.09587567299604416, 0.22060821950435638, 0.0]
# Running Fold 5 / 5
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 124, 100)          1632100
# _________________________________________________________________
# dense_9 (Dense)              (None, 124, 300)          30300
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 37200)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 3)                 111603
# =================================================================
# Total params: 1,774,003
# Trainable params: 141,903
# Non-trainable params: 1,632,100
# _________________________________________________________________
# None
# Training:
# Train on 8222 samples, validate on 1028 samples
# Epoch 1/6
# 8222/8222 [==============================] - 3s 332us/step - loss: 1.1848 - mean_squared_error: 1.1848 - mean_absolute_error: 0.7297 - js_distance: 0.0000e+00 - val_loss: 0.1152 - val_mean_squared_error: 0.1152 - val_mean_absolute_error: 0.2497 - val_js_distance: 0.0000e+00
# Epoch 2/6
# 8222/8222 [==============================] - 3s 317us/step - loss: 0.1075 - mean_squared_error: 0.1075 - mean_absolute_error: 0.2422 - js_distance: 0.0000e+00 - val_loss: 0.1025 - val_mean_squared_error: 0.1025 - val_mean_absolute_error: 0.2308 - val_js_distance: 0.0000e+00
# Epoch 3/6
# 8222/8222 [==============================] - 3s 318us/step - loss: 0.0985 - mean_squared_error: 0.0985 - mean_absolute_error: 0.2275 - js_distance: 0.0000e+00 - val_loss: 0.0983 - val_mean_squared_error: 0.0983 - val_mean_absolute_error: 0.2238 - val_js_distance: 0.0000e+00
# Epoch 4/6
# 8222/8222 [==============================] - 3s 318us/step - loss: 0.0942 - mean_squared_error: 0.0942 - mean_absolute_error: 0.2202 - js_distance: 0.0000e+00 - val_loss: 0.0959 - val_mean_squared_error: 0.0959 - val_mean_absolute_error: 0.2211 - val_js_distance: 0.0000e+00
# Epoch 5/6
# 8222/8222 [==============================] - 3s 318us/step - loss: 0.0923 - mean_squared_error: 0.0923 - mean_absolute_error: 0.2178 - js_distance: 0.0000e+00 - val_loss: 0.0948 - val_mean_squared_error: 0.0948 - val_mean_absolute_error: 0.2187 - val_js_distance: 0.0000e+00
# Epoch 6/6
# 8222/8222 [==============================] - 3s 317us/step - loss: 0.0904 - mean_squared_error: 0.0904 - mean_absolute_error: 0.2156 - js_distance: 0.0000e+00 - val_loss: 0.0955 - val_mean_squared_error: 0.0955 - val_mean_absolute_error: 0.2208 - val_js_distance: 0.0000e+00
# Evaluating:
# 1027/1027 [==============================] - 0s 127us/step
# Final scores for fold:
# ['loss', 'mean_squared_error', 'mean_absolute_error', 'js_distance'] [0.09692078490379723, 0.09692078083753586, 0.22439144551753998, 0.0]

# %%
if not useHoldout:

  print('Average scores across all folds:')
  for metric_index, metric_name in enumerate(metrics):
    metric_total = 0
    for scores in scores_per_fold:
      metric_total += scores[metric_index + 1]
    print(metric_name, metric_total/n_folds )
  print(scores_per_fold)
# Out:
# Average scores across all folds:
# mean_squared_error 0.09462291747331619
# mean_absolute_error 0.21973379254341124
# <function js_distance at 0x7faf0dafbea0> 0.0
# [[0.09350393219680637, 0.09350394457578659, 0.21720808744430542, 0.0], [0.0934905567521715, 0.09349056333303452, 0.21800269186496735, 0.0], [0.09332361936337064, 0.09332362562417984, 0.21845851838588715, 0.0], [0.09587565748548786, 0.09587567299604416, 0.22060821950435638, 0.0], [0.09692078490379723, 0.09692078083753586, 0.22439144551753998, 0.0]]

# %% [markdown]
# Holdout

# %%
from sklearn.model_selection import train_test_split

if useHoldout:
  print("HOLDOUT")

  data_train, data_test, labels_train, labels_test = train_test_split(data, labels, test_size=0.2, shuffle=True)



  #process
  # vectorizer = CountVectorizer(max_features=5000)
  # # vectorizer = CountVectorizer(binary=True, stop_words=stopwords.words('english'), 
  # #                             lowercase=True, min_df=3, max_df=0.9, max_features=5000)
  # data_train = vectorizer.fit_transform(data_train.astype('U'))

  # data_test = vectorizer.transform(data_test.astype('U'))
  # end

  # encoded_data_train = tk.texts_to_sequences(data_train)
  # padded_data_train = pad_sequences(encoded_data_train, maxlen=max_length, padding='post')
  # data_train = padded_data_train

  # encoded_data_test = tk.texts_to_sequences(data_test)
  # padded_data_test = pad_sequences(encoded_data_test, maxlen=max_length, padding='post')
  # data_test = padded_data_test

  model = None # Clearing the NN.
  model = create_model(embedding_layer)

  scores = train_and_evaluate_model(model, data_train, labels_train, data_test, labels_test)
  # print(model.metrics_names, scores)

# %%
filename = './drive/My Drive/Colab Notebooks/react_model.h5'
model.save(filename)
