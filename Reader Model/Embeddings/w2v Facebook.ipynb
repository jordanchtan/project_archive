# %%
from google.colab import drive
drive.mount('/content/drive')

path = './drive/My Drive/Colab Notebooks/Store/fb_corpus.txt'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# imports needed and logging
import gzip
import gensim 
import logging
 
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)

# %%
with open(path, 'r', encoding='utf16') as f:
        for i,line in enumerate (f):
            print(line)
            break
# Out:
# chief justice roberts responds to judicial ethics critics

# %%
def read_input(input_file):
    """This method reads the input file which is in gzip format"""
 
    logging.info("reading file {0}...this may take a while".format(input_file))
    with open(input_file, 'r', encoding='utf16') as f:
        for i, line in enumerate(f):
 
            if (i % 10000 == 0):
                logging.info("read {0} reviews".format(i))
            # do some pre-processing and return list of words for each review
            # text
            yield gensim.utils.simple_preprocess(line)

# %%
documents = []

for x in read_input(path):
  documents.append(x)
print(documents[0])
# Out:
# 2020-04-20 10:01:02,513 : INFO : reading file ./drive/My Drive/Colab Notebooks/Store/fb_corpus.txt...this may take a while
# 2020-04-20 10:01:02,515 : INFO : read 0 reviews
# 2020-04-20 10:01:02,645 : INFO : read 10000 reviews
# 2020-04-20 10:01:02,779 : INFO : read 20000 reviews
# 2020-04-20 10:01:02,911 : INFO : read 30000 reviews
# 2020-04-20 10:01:03,022 : INFO : read 40000 reviews
# 2020-04-20 10:01:03,149 : INFO : read 50000 reviews
# 2020-04-20 10:01:03,282 : INFO : read 60000 reviews
# 2020-04-20 10:01:03,414 : INFO : read 70000 reviews
# 2020-04-20 10:01:03,617 : INFO : read 80000 reviews
# 2020-04-20 10:01:03,730 : INFO : read 90000 reviews
# 2020-04-20 10:01:03,858 : INFO : read 100000 reviews
# 2020-04-20 10:01:03,998 : INFO : read 110000 reviews
# 2020-04-20 10:01:04,138 : INFO : read 120000 reviews
# 2020-04-20 10:01:04,276 : INFO : read 130000 reviews
# 2020-04-20 10:01:04,402 : INFO : read 140000 reviews
# 2020-04-20 10:01:04,529 : INFO : read 150000 reviews
# ...

# %%
# # build vocabulary and train model
# model = gensim.models.Word2Vec(
#     documents,
#     size=150,
#     window=10,
#     min_count=2,
#     workers=10,
#     iter=10)

model = gensim.models.Word2Vec(documents)
# Out:
# 2020-04-20 10:01:08,605 : INFO : collecting all words and their counts
# 2020-04-20 10:01:08,607 : INFO : PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# 2020-04-20 10:01:08,631 : INFO : PROGRESS: at sentence #10000, processed 77989 words, keeping 11828 word types
# 2020-04-20 10:01:08,652 : INFO : PROGRESS: at sentence #20000, processed 169306 words, keeping 16022 word types
# 2020-04-20 10:01:08,675 : INFO : PROGRESS: at sentence #30000, processed 258119 words, keeping 19155 word types
# 2020-04-20 10:01:08,699 : INFO : PROGRESS: at sentence #40000, processed 330480 words, keeping 22334 word types
# 2020-04-20 10:01:08,722 : INFO : PROGRESS: at sentence #50000, processed 413044 words, keeping 24825 word types
# 2020-04-20 10:01:08,750 : INFO : PROGRESS: at sentence #60000, processed 497233 words, keeping 26556 word types
# 2020-04-20 10:01:08,776 : INFO : PROGRESS: at sentence #70000, processed 584535 words, keeping 27892 word types
# ...

# %%
print(model)
# summarize vocabulary
words = list(model.wv.vocab)
print(words)
# # access vector for one word
print(model['kills'])

model.wv.most_similar(positive='kills', topn=6)
# Out:
# Word2Vec(vocab=26255, size=100, alpha=0.025)
# ...

# %%
from gensim.models.keyedvectors import KeyedVectors

# model.wv.save_word2vec_format('fb_w2v_model.txt', binary=False)
model.wv.save_word2vec_format('./drive/My Drive/Colab Notebooks/Store/fb_w2v_model.txt', binary=False)
# model.wv.save('./drive/My Drive/Colab Notebooks/Store/fb_w2v_model.bin', encodi)
# model.save('./drive/My Drive/Colab Notebooks/Store/fb_w2v_model.bin')
# Out:
# 2020-04-20 11:18:44,703 : INFO : storing 26255x100 projection weights into ./drive/My Drive/Colab Notebooks/Store/fb_w2v_model.txt
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:253: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL

# %%
# # save model
# model.save('model.bin')
# # load model
# new_model = model.wv.load_word2vec_format('model.bin')
# print(new_model)
# Out:
# 2020-04-20 11:05:22,327 : INFO : saving Word2Vec object under model.bin, separately None
# 2020-04-20 11:05:22,328 : INFO : not storing attribute vectors_norm
# 2020-04-20 11:05:22,328 : INFO : not storing attribute cum_table
# /usr/local/lib/python3.6/dist-packages/smart_open/smart_open_lib.py:253: UserWarning: This function is deprecated, use smart_open.open instead. See the migration notes for details: https://github.com/RaRe-Technologies/smart_open/blob/master/README.rst#migrating-to-the-new-open-function
#   'See the migration notes for details: %s' % _MIGRATION_NOTES_URL
# 2020-04-20 11:05:22,595 : INFO : saved model.bin
# 2020-04-20 11:05:22,597 : INFO : loading projection weights from model.bin
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-25-19feb668cc12> in <module>()
#       1 model.save('model.bin')
#       2 # load model
# ...
