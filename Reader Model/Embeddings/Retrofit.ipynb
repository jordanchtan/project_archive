# %%
# !git clone https://github.com/jordanchtan/indiv-proj-retro.git
# Out:
# Cloning into 'indiv-proj-retro'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 15 (delta 0), reused 15 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd indiv-proj-retro/
# !python retrofit.py -i ../drive/"My Drive"/"Colab Notebooks"/Store/no_first_fb_w2v_model.txt -l ../drive/"My Drive"/"Colab Notebooks"/Store/NRC.txt -n 10 -o ../drive/"My Drive"/"Colab Notebooks"/Store/retro_fb_w2v_model.txt

# need manual add back og top line
# Out:
# /content/indiv-proj-retro
# Vectors read from: ../drive/My Drive/Colab Notebooks/Store/no_first_fb_w2v_model.txt
#
# Writing down the vectors in ../drive/My Drive/Colab Notebooks/Store/retro_fb_w2v_model.txt
